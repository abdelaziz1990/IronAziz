# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import datetime
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
df  = pd.read_excel(r'C:\Users\Mtime\OneDrive\Bureau\example_data_cleaning.xlsx')
df
# Out:
#     TransactionID  ClientID    BirthYear   Amount   Profession  Department  \
# 0               1     34982  2013.000000    12900      Student          78
# 1               2     34983  2015.000000     1230       barmen          78
# 2               3     34984  1945.000000     3450      student          78
# 3               4     34985  1923.000000     5670      manager          78
# 4               5     34986  1978.000000     7890           hr          78
# 5               6     34987  1967.000000    10110      Manager          78
# 6              15     34987  1967.000000    30090      Manager          78
# 7              22     34987          NaN    18990       sailer          78
# 8               7     34988          NaN    12330      Manager          78
# 9              23     34988  1999.000000    25650      Manager          78
# 10              8     34989  1958.000000    14550           HR          78
# ...

# %%
df.describe()
# Out:
#        TransactionID      ClientID    BirthYear        Amount  Department
# count      30.000000     30.000000    28.000000  3.000000e+01        30.0
# mean       15.500000  34993.833333  1968.316327  1.010097e+05        78.0
# std         8.803408      8.132876    27.963867  4.342616e+05         0.0
# min         1.000000  34982.000000  1923.000000  1.230000e+03        78.0
# 25%         8.250000  34987.250000  1944.714286  1.233000e+04        78.0
# 50%        15.500000  34991.500000  1967.000000  1.899000e+04        78.0
# 75%        22.750000  34999.750000  1988.000000  2.953500e+04        78.0
# max        30.000000  35008.000000  2017.000000  2.399090e+06        78.0

# %%
df.isna().sum()
# Out:
# TransactionID    0
# ClientID         0
# BirthYear        2
# Amount           0
# Profession       2
# Department       0
# Risk             0
# dtype: int64

# %%
df.dtypes
# Out:
# TransactionID      int64
# ClientID           int64
# BirthYear        float64
# Amount             int64
# Profession        object
# Department         int64
# Risk              object
# dtype: object

# %%
df.drop(['Department'], axis=1)
# Out:
#     TransactionID  ClientID    BirthYear   Amount   Profession    Risk
# 0               1     34982  2013.000000    12900      Student     Low
# 1               2     34983  2015.000000     1230       barmen    High
# 2               3     34984  1945.000000     3450      student  Medium
# 3               4     34985  1923.000000     5670      manager     Low
# 4               5     34986  1978.000000     7890           hr    High
# 5               6     34987  1967.000000    10110      Manager  Medium
# 6              15     34987  1967.000000    30090      Manager     Low
# 7              22     34987          NaN    18990       sailer    High
# 8               7     34988          NaN    12330      Manager  Medium
# 9              23     34988  1999.000000    25650      Manager     Low
# 10              8     34989  1958.000000    14550           HR    High
# 11             24     34989  1967.000000    27870           HR  Medium
# ...

# %%
df['BirthYear'] = df['BirthYear'].fillna(0)

# %%
df['BirthYear'] = df['BirthYear'].astype(int)

# %%
df.drop('Department',axis=1, inplace=True)
# i delete this column because we have just one value, so is not to important....

# %%
df.at[7,'BirthYear']=1967
# i delete the Nan value and i remplaced with a true BirthYear
df.at[8,'BirthYear']=1999
#the same think here...

# %%
df['Profession'] = df['Profession'].fillna(0)
# i remplaced all the Nan value By 0..

# %%
df.at[28,'Profession']='bdm'
df.at[29,'Profession']='bdm'
# i change the 0 value by the bdm string.

# %%
df['Profession'] = df['Profession'].str.upper()

# %%
df.drop([19], inplace=True)
# i drop the row 19 because i think that is not true to have a DEVELOPER with a birthYear at 1923....

# %%
df.at[20,'Profession']='STUDENT'
df.at[21,'Profession']='STUDENT'
df.at[26,'Profession']='STUDENT'

# %%
df.at[29,'BirthYear']=1967
#here i change the birthYear because is the same personne here, just mistake...

# %%
df.at[17,'BirthYear']=1966
# so to have i licence to drive a car i think you must have at least 20, here the bearthYear of Driver is 2017, so i chaged 
#to 1966 better than droped the row

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount   Profession    Risk
# 0               1     34982       2013   12900      STUDENT     Low
# 1               2     34983       2015    1230       BARMEN    High
# 2               3     34984       1945    3450      STUDENT  Medium
# 3               4     34985       1923    5670      MANAGER     Low
# 4               5     34986       1978    7890           HR    High
# 5               6     34987       1967   10110      MANAGER  Medium
# 6              15     34987       1967   30090      MANAGER     Low
# 7              22     34987       1967   18990       SAILER    High
# 8               7     34988       1999   12330      MANAGER  Medium
# 9              23     34988       1999   25650      MANAGER     Low
# 10              8     34989       1958   14550           HR    High
# 11             24     34989       1967   27870           HR  Medium
# 12              9     34990       1953   16770      MANAGER  Medium
# ...

# %%
df_encoder = LabelEncoder()
df['Profession'] = df_encoder.fit_transform(df['Profession'])
df['Risk'] = df_encoder.fit_transform(df['Risk'])

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount  Profession  Risk
# 0               1     34982       2013   12900           9     1
# 1               2     34983       2015    1230           0     0
# 2               3     34984       1945    3450           9     2
# 3               4     34985       1923    5670           5     1
# 4               5     34986       1978    7890           4     0
# 5               6     34987       1967   10110           5     2
# 6              15     34987       1967   30090           5     1
# 7              22     34987       1967   18990           8     0
# 8               7     34988       1999   12330           5     2
# 9              23     34988       1999   25650           5     1
# 10              8     34989       1958   14550           4     0
# 11             24     34989       1967   27870           4     2
# 12              9     34990       1953   16770           5     2
# ...
