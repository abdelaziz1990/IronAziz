# %% [markdown]
# # Lab_10_Module_2

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# # Challenge 1

# %%
df = pd.read_excel(r'C:\Users\Mtime\OneDrive\Bureau\Temp_States.xlsx')
df.head()
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444

# %%
# here we have like statistiq data

# %% [markdown]
# 1.1.Select the rows where state is New York.

# %%
idx = df['State']=='New York'
df_New_York = df.loc[idx]
df_New_York
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# 1.2.What is the average temperature of cities in New York?

# %%
df['Temperature'].mean()
# Out:
# 15.15873015873016

# %% [markdown]
# 1.3.Which states and cities have a temperature above 15 degrees Celsius?

# %%
x = df.loc[df['Temperature'] > 15]
x
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# 1.4.Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
df.loc[df['Temperature'] > 15, ['City']]
# Out:
#        City
# 0       NYC
# 3  Hartford
# 5    Treton
# 6    Newark

# %% [markdown]
# 1.5.Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?

# %%
df.loc[(df['Temperature']>15) & (df['Temperature']<20)]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# 1.6.Find the mean and standard deviation of the temperature of each state.

# %%
df.groupby('State')['Temperature'].mean()
# Out:
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741
# Name: Temperature, dtype: float64

# %%
df.groupby('State')['Temperature'].std()
# Out:
# State
# Connecticut    1.964186
# New Jersey     1.571348
# New York       8.133404
# Name: Temperature, dtype: float64

# %% [markdown]
# # Challenge 2

# %%
df = pd.read_excel(r'C:\Users\Mtime\OneDrive\Bureau\employee.xlsx')
df
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 3        Admin    Master         VP  Manuella     15      33
# 4        Sales    Master    Analyst     Carla      6      38
# ..         ...       ...        ...       ...    ...     ...
# 495      Sales       PhD         VP    Calvin      2     119
# 496         HR    Master    Analyst    Dustin      6      67
# 497      Sales       PhD         VP   Winston     13      93
# 498         IT       PhD    Analyst      Earl     12     108
# 499      Sales    Master    Analyst     Alvin     13      48
#
# [500 rows x 6 columns]

# %% [markdown]
# 2.1.What's the average salary in this company?

# %%
df['Salary'].mean()
# Out:
# 73.528

# %% [markdown]
# 2.2.What's the highest salary?

# %%
df['Salary'].max()
# Out:
# 120

# %% [markdown]
# 2.3.What's the lowest salary?

# %%
df['Salary'].min()
# Out:
# 30

# %% [markdown]
# 2.4.Who are the employees with the lowest salary?

# %%
x=df.groupby('Salary')['Name'].min()
x.head()
# Out:
# Salary
# 30      Adam
# 31      Chad
# 32     Alvin
# 33    Carlos
# 34    Dustin
# Name: Name, dtype: object

# %% [markdown]
# 2.5.Find all the information about an employee called David.

# %%
df.loc[df['Name'] == 'David']
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# 2.6. Could you return only David's salary?

# %%
df['Salary'].loc[df['Name']== 'David']
# Out:
# 0      58
# 124    31
# Name: Salary, dtype: int64

# %% [markdown]
# 1.7.Print all the rows where job title is associate.

# %%
#df.loc[df.Title == 'associate']
df.loc[df.Title == 'associate']
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# 1.8. Print the first 3 rows of your dataframe.

# %%
df.head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
df[:3]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %% [markdown]
# 1.9.Find the employees whose title is associate and whose salary is above 55.

# %%
df.loc[(df['Title'] == 'associate') & (df['Salary'] > 55)]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 9        Admin    Master  associate    Kareem      3     104
# 10       Admin    Master  associate   Cynthia      1     114
# 16       Admin  Bachelor  associate    Shanon      1      99
# 18       Admin  Bachelor  associate     Megan      9      79
# ..         ...       ...        ...       ...    ...     ...
# 476      Admin       PhD  associate      Greg      8      93
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [104 rows x 6 columns]

# %% [markdown]
# 1.10.Group the employees by number of years of employment. What are the average salaries in each group?

# %%
df.groupby(['Years']).mean()['Salary']
# Out:
# Years
# 1     75.863636
# 2     75.857143
# 3     74.571429
# 4     77.129032
# 5     73.857143
# 6     72.382353
# 7     73.840000
# 8     64.250000
# 9     76.741935
# 10    73.351351
# 11    74.866667
# 12    73.454545
# 13    71.935484
# 14    70.968750
# 15    69.758621
# Name: Salary, dtype: float64

# %% [markdown]
# 1.11.What is the average salary per title?

# %%
df.groupby(['Title']).mean()['Salary']
# Out:
# Title
# Analyst      73.703911
# VP           72.907975
# associate    73.968354
# Name: Salary, dtype: float64

# %% [markdown]
# 1.12.Find the salary quartiles.

# %%
df['Salary'].quantile([.1, .25, .5, .75])
# Out:
# 0.10    38.0
# 0.25    50.0
# 0.50    72.0
# 0.75    97.0
# Name: Salary, dtype: float64

# %% [markdown]
# 1.13.Is the mean salary different per gender?

# %%
df.groupby(['Gender']).mean()['Salary']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4840/3719010613.py in <module>
# ----> 1 df.groupby(['Gender']).mean()['Salary']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# ...

# %% [markdown]
# 1.14.Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
df.groupby(['Department']).agg(['mean', 'min', 'max'])
# Out:
#                Years             Salary
#                 mean min max       mean min  max
# Department
# Admin       7.642276   1  15  76.325203  30  120
# HR          7.172131   1  15  74.237705  30  119
# IT          8.141791   1  15  70.671642  30  120
# Sales       7.206612   1  15  73.132231  30  120

# %% [markdown]
# # Challenge 3

# %% [markdown]
# 3.1.Open the Orders dataset. Name your dataset orders.

# %%
Orders = pd.read_excel(r'C:\Users\Mtime\OneDrive\Bureau\Orders.xlsx')
Orders.head(5)
# Out:
#    Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 0         0.0   536365.0    85123A  2010.0   12.0  3.0   8.0
# 1         1.0   536365.0   71053.0  2010.0   12.0  3.0   8.0
# 2         2.0   536365.0    84406B  2010.0   12.0  3.0   8.0
# 3         3.0   536365.0    84029G  2010.0   12.0  3.0   8.0
# 4         4.0   536365.0    84029E  2010.0   12.0  3.0   8.0
#
#                            Description  Quantity         InvoiceDate  \
# 0   white hanging heart t-light holder       6.0 2010-12-01 08:26:00
# 1                  white metal lantern       6.0 2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger       8.0 2010-12-01 08:26:00
# 3  knitted union flag hot water bottle       6.0 2010-12-01 08:26:00
# 4       red woolly hottie white heart.       6.0 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55     17850.0  United Kingdom         15.30
# 1       3.39     17850.0  United Kingdom         20.34
# ...

# %%
Orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# 3.1.What is the average purchase price?

# %%
Orders['UnitPrice'].mean()
# Out:
# 3.116174480549152

# %% [markdown]
# 3.2.What are the highest and lowest purchase prices?

# %%
Orders['UnitPrice'].min()
# Out:
# 0.0

# %%
Orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# 3.3.Select all the customers from Spain.

# %%
a = Orders.loc[(Orders['Country'] == 'Spain') &(Orders['CustomerID'])]

# %% [markdown]
# 3.4.How many customers do we have in Spain?

# %%
len(a)
# Out:
# 2485

# %% [markdown]
# 3.5.Select all the customers who have bought more than 50 items.

# %%
Orders.loc[(Orders['Quantity']> 50)&(Orders['CustomerID'])]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 46            46.0   536371.0   22086.0  2010.0   12.0  3.0   9.0
# 83            83.0   536376.0   21733.0  2010.0   12.0  3.0   9.0
# 96            96.0   536378.0   21212.0  2010.0   12.0  3.0   9.0
# 102          102.0   536378.0    85071B  2010.0   12.0  3.0   9.0
# 174          176.0   536386.0    85099C  2010.0   12.0  3.0   9.0
# ...            ...        ...       ...     ...    ...  ...   ...
# 397720    541702.0   581566.0   23404.0  2011.0   12.0  5.0  11.0
# 397721    541703.0   581567.0   21417.0  2011.0   12.0  5.0  11.0
# 397729    541711.0   581567.0   21326.0  2011.0   12.0  5.0  11.0
# 397761    541746.0   581571.0   23167.0  2011.0   12.0  5.0  12.0
# 397882    541867.0   581584.0   20832.0  2011.0   12.0  5.0  12.0
#
#                                Description  Quantity         InvoiceDate  \
# 46          paper chain kit 50's christmas      80.0 2010-12-01 09:00:00
# ...

# %% [markdown]
# 3.6.Select orders from Spain that include more than 50 items.

# %%
Orders.loc[(Orders['Country']=='Spain')&(Orders['Quantity'] > 50)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 4250        6421.0   536944.0   22383.0  2010.0   12.0  5.0  12.0
# 4251        6422.0   536944.0   22384.0  2010.0   12.0  5.0  12.0
# 4252        6423.0   536944.0   20727.0  2010.0   12.0  5.0  12.0
# 4253        6424.0   536944.0   20725.0  2010.0   12.0  5.0  12.0
# 4254        6425.0   536944.0   20728.0  2010.0   12.0  5.0  12.0
# 32454      52416.0   540785.0    84997B  2011.0    1.0  2.0  11.0
# 32455      52417.0   540785.0    84997D  2011.0    1.0  2.0  11.0
# 32456      52418.0   540785.0    84997C  2011.0    1.0  2.0  11.0
# 32457      52419.0   540785.0    84997A  2011.0    1.0  2.0  11.0
# 91155     136767.0   547972.0   22383.0  2011.0    3.0  1.0  16.0
# 91156     136768.0   547972.0   22384.0  2011.0    3.0  1.0  16.0
# 91159     136771.0   547972.0   20728.0  2011.0    3.0  1.0  16.0
# 174442    248797.0   558871.0   22384.0  2011.0    7.0  1.0  13.0
# ...

# %% [markdown]
# 1.7.Select all free orders.

# %%
Orders.loc[Orders.amount_spent==0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 6914        9302.0   537197.0   22841.0  2010.0   12.0  7.0  14.0
# 22539      33576.0   539263.0   22580.0  2010.0   12.0  4.0  14.0
# 25379      40089.0   539722.0   22423.0  2010.0   12.0  2.0  13.0
# 29080      47068.0   540372.0   22090.0  2011.0    1.0  4.0  16.0
# 29082      47070.0   540372.0   22553.0  2011.0    1.0  4.0  16.0
# 34494      56674.0   541109.0   22168.0  2011.0    1.0  4.0  15.0
# 53788      86789.0   543599.0    84535B  2011.0    2.0  4.0  13.0
# 85671     130188.0   547417.0   22062.0  2011.0    3.0  3.0  10.0
# 92875     139453.0   548318.0   22055.0  2011.0    3.0  3.0  12.0
# 97430     145208.0   548871.0   22162.0  2011.0    4.0  1.0  14.0
# 107192    157042.0   550188.0   22636.0  2011.0    4.0  4.0  18.0
# 128641    187613.0   553000.0   47566.0  2011.0    5.0  4.0  15.0
# 137127    198383.0   554037.0   22619.0  2011.0    5.0  5.0  14.0
# ...

# %% [markdown]
# 3.8.Select all orders whose description starts with lunch bag.

# %%
Orders.loc[(Orders.Description.str.startswith('lunch bag'))]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 93            93.0   536378.0   20725.0  2010.0   12.0  3.0   9.0
# 172          174.0   536385.0   22662.0  2010.0   12.0  3.0   9.0
# 354          363.0   536401.0   22662.0  2010.0   12.0  3.0  11.0
# 359          368.0   536401.0   20725.0  2010.0   12.0  3.0  11.0
# 360          369.0   536401.0   22382.0  2010.0   12.0  3.0  11.0
# ...            ...        ...       ...     ...    ...  ...   ...
# 397465    540436.0   581486.0   23207.0  2011.0   12.0  5.0   9.0
# 397713    541695.0   581538.0   20727.0  2011.0   12.0  5.0  11.0
# 397714    541696.0   581538.0   20725.0  2011.0   12.0  5.0  11.0
# 397877    541862.0   581581.0   23681.0  2011.0   12.0  5.0  12.0
# 397880    541865.0   581583.0   20725.0  2011.0   12.0  5.0  12.0
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot      10.0 2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# 3.9.Select all lunch bag orders made in 2011.

# %%
Orders.loc[(Orders.Description.str.startswith('lunch bag'))&(Orders['year']==2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 26340      42678.0   540015.0   20725.0  2011.0    1.0  2.0  11.0
# 26341      42679.0   540015.0   20726.0  2011.0    1.0  2.0  11.0
# 26512      42851.0   540023.0   22382.0  2011.0    1.0  2.0  12.0
# 26513      42852.0   540023.0   20726.0  2011.0    1.0  2.0  12.0
# 26860      43616.0   540098.0   22384.0  2011.0    1.0  2.0  15.0
# ...            ...        ...       ...     ...    ...  ...   ...
# 397465    540436.0   581486.0   23207.0  2011.0   12.0  5.0   9.0
# 397713    541695.0   581538.0   20727.0  2011.0   12.0  5.0  11.0
# 397714    541696.0   581538.0   20725.0  2011.0   12.0  5.0  11.0
# 397877    541862.0   581581.0   23681.0  2011.0   12.0  5.0  12.0
# 397880    541865.0   581583.0   20725.0  2011.0   12.0  5.0  12.0
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot      10.0 2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# 3.10.Show the frequency distribution of the amount spent in Spain.

# %%
Orders.loc[Orders.Country=='Spain']['amount_spent'].hist(bins = 20)
#Orders.loc[Orders['Country'] == 'Spain'].values_count()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 3.11.Select all orders made in the month of August.

# %%
Orders.loc[Orders['month']==8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 199475    285421.0   561904.0   22075.0  2011.0    8.0  1.0   8.0
# 199476    285422.0   561904.0    85049E  2011.0    8.0  1.0   8.0
# 199477    285423.0   561905.0   21385.0  2011.0    8.0  1.0   9.0
# 199478    285424.0   561905.0    84970L  2011.0    8.0  1.0   9.0
# 199479    285425.0   561905.0    84970S  2011.0    8.0  1.0   9.0
# ...            ...        ...       ...     ...    ...  ...   ...
# 226483    320688.0   565067.0   22644.0  2011.0    8.0  3.0  17.0
# 226484    320689.0   565067.0   22645.0  2011.0    8.0  3.0  17.0
# 226485    320690.0   565067.0   22637.0  2011.0    8.0  3.0  17.0
# 226486    320691.0   565067.0   22646.0  2011.0    8.0  3.0  17.0
# 226487    320692.0   565067.0   22741.0  2011.0    8.0  3.0  17.0
#
#                                 Description  Quantity         InvoiceDate  \
# 199475          6 ribbons elegant christmas      96.0 2011-08-01 08:30:00
# ...

# %% [markdown]
# 3.12.Find the number of orders made by each country in the month of August.

# %%
X=Orders.loc[Orders['month']==8]['Country'].value_counts()
X.head()
# Out:
# United Kingdom    23105
# Germany             795
# EIRE                593
# France              569
# Netherlands         280
# Name: Country, dtype: int64

# %% [markdown]
# 3.13.What's the average amount of money spent by country?

# %%
Orders.groupby('Country')['amount_spent'].mean()
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# 3.14.What's the most expensive item?

# %%
Orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# 3.15.What is the average amount spent per year?

# %%
Orders.groupby('year')['amount_spent'].mean()
# Out:
# year
# 2010.0    21.892733
# 2011.0    22.430074
# Name: amount_spent, dtype: float64
