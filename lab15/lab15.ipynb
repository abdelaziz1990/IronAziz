# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1635761607, todate=1638267207)
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 294,
#  'total': 0,
#  'items': [{'tags': ['python', 'rest', 'cherrypy', 'http-method'],
#    'owner': {'reputation': 1,
#     'user_id': 17404650,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a47cf9455fd9533cf9ab630e6e8ab7c4?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'costola',
#     'link': 'https://stackoverflow.com/users/17404650/costola'},
#    'is_answered': False,
#    'view_count': 17,
#    'answer_count': 1,
#    'score': -1,
#    'last_activity_date': 1639268289,
#    'creation_date': 1636989664,
#    'question_id': 69976740,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69976740/cherrypy-rest-how-can-i-pass-an-optional-argument-to-the-get-function-that-if',
# ...

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers', fromdate=1635761607, todate=1638267207)
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 290,
#  'total': 0,
#  'items': [{'owner': {'reputation': 420,
#     'user_id': 2244093,
#     'user_type': 'registered',
#     'accept_rate': 23,
#     'profile_image': 'https://i.stack.imgur.com/bijRS.jpg?s=256&g=1',
#     'display_name': 'daniel assayag',
#     'link': 'https://stackoverflow.com/users/2244093/daniel-assayag'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1639267926,
#    'last_edit_date': 1639267926,
#    'creation_date': 1637678971,
#    'answer_id': 70082967,
#    'question_id': 8087714,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 16635713,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GglI7fA48oOthdkY5WoiTYnxrqz2aPbPYeahmM=k-s256',
#     'display_name': 'Rythorian Ethrovon',
# ...

# %%
#Find the most voted question today with at least a score of 5 and tagged with 'python'.
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1635761607, todate=1638267207, tagged='python', score=5)
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 282,
#  'total': 0,
#  'items': [{'tags': ['python', 'rest', 'cherrypy', 'http-method'],
#    'owner': {'reputation': 1,
#     'user_id': 17404650,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a47cf9455fd9533cf9ab630e6e8ab7c4?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'costola',
#     'link': 'https://stackoverflow.com/users/17404650/costola'},
#    'is_answered': False,
#    'view_count': 17,
#    'answer_count': 1,
#    'score': -1,
#    'last_activity_date': 1639268289,
#    'creation_date': 1636989664,
#    'question_id': 69976740,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/69976740/cherrypy-rest-how-can-i-pass-an-optional-argument-to-the-get-function-that-if',
# ...

# %%
#Find the answers with id 6784 and 6473.
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('badges', ids=[6784, 6473])
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 281,
#  'total': 0,
#  'items': [{'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'silver',
#    'badge_id': 6784,
#    'link': 'https://stackoverflow.com/badges/6784/asterisk',
#    'name': 'asterisk'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'gold',
#    'badge_id': 6473,
#    'link': 'https://stackoverflow.com/badges/6473/sql-server-2012',
#    'name': 'sql-server-2012'}]}
