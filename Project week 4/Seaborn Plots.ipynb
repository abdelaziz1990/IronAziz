# %%
import pandas as pd
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

diamonds = pd.read_csv(r'C:\Users\Mtime\OneDrive\Bureau\diamonds_clean.csv')
diamonds.drop(['Unnamed: 0'] , axis=1 , inplace=True)
#diamonds.drop(['Unnamed: 0.1'] , axis=1 , inplace=True)
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y  z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ... ..
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3
#
#        new_clarity
# 0                1
# 1                2
# ...

# %% [markdown]
# from IPython.display import Imag![diamond.png](attachment:diamond.png)e
# Image("C:\Users\Mtime\OneDrive\Bureau\diamond.png")

# %% [markdown]
# 1.1. carat vs depth

# %%
#scatterplot It gives between relationship carat and depth

sns.scatterplot(x="carat",y="depth",hue="price",
               
                sizes=(1, 8), linewidth=0,
                data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='depth'>

# %% [markdown]
# 1.2. carat density

# %%
#Kdeplot Carat vs Price
sns.kdeplot(diamonds['carat'], shade=True , color='r')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='Density'>

# %% [markdown]
# 1.3.the distrubition of price with cut

# %% [markdown]
# ![color.png](attachment:color.png)

# %%
#Catplot inside Seaborn function is significiant for me because of awesome . It contributes to Visualization.
sns.catplot(x="cut",y="price",hue="color",kind="point",data=diamonds)

# %% [markdown]
# 1.4. boxplot of color with the price

# %%
sns.boxplot (x="color",y="price",data=diamonds);
# Generally if carat greater than 3 or 2.5 is the outlier value.

# %% [markdown]
# 1.5.the destrubition of price with carat

# %%
#LMPLOT I think it offers smooth visuals that is why i am always using that method.I think,
z=sns.lmplot(x="price",y="carat",hue = 'color',  data=diamonds)

# %% [markdown]
# 1.6. the distrubition for all the columns

# %%
sns.factorplot(data=diamonds , kind='box' , size=7, aspect=2.5)
#The Values are Distributed over a Small Scale.
# Out:
# C:\Users\Mtime\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Mtime\anaconda3\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 1.7.the count of cut

# %% [markdown]
# ![cut.png](attachment:cut.png)

# %%
p = sns.factorplot(x='cut', data=diamonds , kind='count',aspect=2.5 )

# %% [markdown]
# 1.8. the corr map

# %%
ax=sns.heatmap(diamonds.corr(),linewidth=10.1,annot=True,center=1)

# %% [markdown]
# 1.9. 3D plot in seaborn

# %%
sns.set(style = "darkgrid")

fig = plt.figure(figsize = (20, 20))
ax = fig.add_subplot(111, projection = '3d')

x = diamonds['price']
y = diamonds['carat']
z = diamonds['depth']
fig.set_facecolor('white')
ax.set_facecolor('green')
ax.set_xlabel("price")
ax.set_ylabel("carat")
ax.set_zlabel("depth")

ax.scatter(x, y, z)

plt.show()

# %% [markdown]
# 1.10. Pie chart

# %%
labels = diamonds.cut.unique().tolist()
sizes = diamonds.cut.value_counts().tolist()
fig = plt.figure(figsize = (10, 10))
colors = sns.color_palette('bright')[0:8]
plt.pie(sizes, labels=labels,colors = colors, autopct='%.0f%%')
plt.title("Percentage of cut Categories")
plt.show()
